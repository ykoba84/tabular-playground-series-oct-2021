# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
train = pd.read_csv('../input/train.csv', nrows=1000)

# %%
x = np.arange(-5, 5, 0.1)
y = np.sin(x)
plt.plot(x,y)
plt.show()
